# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backer_info_df = pd.read_csv("backer_info.csv")
backer_info_df.head(10)
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# 5           {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# 6              {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# 7          {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# 8           {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# 9           {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
backer_values = []
for i, row in backer_info_df.iterrows():
    data = row[0]
    converted_data = json.loads(data)
    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
    row_values = converted_data.values()
    
    # Append the list of values for each row to a list. 
    backer_values.append(row_values)

# Print out the list of values for each row.
print(backer_values)
# Out:
# [dict_values(['av166', 968, 'Angelo Vincent', 'avincent@live.com']), dict_values(['ha127', 563, 'Hubert Arnold', 'harnold@yandex.com']), dict_values(['lg794', 65, 'Loris Goulet', 'lgoulet@yandex.com']), dict_values(['tb566', 563, 'Teodora Brunelli', 'tbrunelli@outlook.com']), dict_values(['lh506', 563, 'Lexie Hunt', 'lhunt@live.com']), dict_values(['lh382', 563, 'Lambert Huber', 'lhuber@live.com']), dict_values(['em444', 563, 'Emmy Morin', 'emorin@live.com']), dict_values(['at582', 1572, 'Armonda Trani', 'atrani@live.com']), dict_values(['id772', 1911, 'Ilana Duke', 'iduke@outlook.com']), dict_values(['lw275', 65, 'Leigha Wright', 'lwright@live.com']), dict_values(['ub509', 65, 'Uwe Becker', 'ubecker@yahoo.com']), dict_values(['ha915', 1572, 'Hawa Audy', 'haudy@gmail.com']), dict_values(['bb881', 968, 'Bia Bonura', 'bbonura@yahoo.com']), dict_values(['mg332', 65, 'Michel Garner', 'mgarner@protonmail.com']), dict_values(['kd700', 1572, 'Karole Dunn', 'kdunn@yahoo.com']), dict_values(['as695', 563, 'Arndt Schreiber', 'aschreiber@yahoo.com']), dict_values(['iv513', 65, 'Imen Villeneuve', 'ivilleneuve@yahoo.com']), dict_values(['ab842', 65, 'Alcina Bonadonna', 'abonadonna@yandex.com']), dict_values(['re181', 1114, 'Raelene Espinoza', 'respinoza@outlook.com']), dict_values(['kn133', 65, 'Kati Nash', 'knash@protonmail.com']), dict_values(['gj893', 65, 'Georg Jager', 'gjager@yahoo.com']), dict_values(['vp915', 948, 'Virgilio Paolella', 'vpaolella@gmail.com']), dict_values(['ja995', 563, 'Jerrica Avila', 'javila@protonmail.com']), dict_values(['ga249', 563, 'Gianni Achterberg', 'gachterberg@live.com']), dict_values(['td403', 65, 'Timoteo Dion', 'tdion@gmail.com']), dict_values(['tv463', 1572, 'Teodoro Verno', 'tverno@yandex.com']), dict_values(['mw606', 65, 'Morris Waller', 'mwaller@protonmail.com']), dict_values(['hc648', 65, 'Hans Chen', 'hchen@yandex.com']), dict_values(['ta379', 563, 'Trilby Auer', 'tauer@yahoo.com']), dict_values(['tj583', 1572, 'Theola Jodoin', 'tjodoin@yandex.com']), dict_values(['tc559', 65, 'Tova Capri', 'tcapri@live.com']), dict_values(['ww629', 65, 'Wanda Walton', 'wwalton@protonmail.com']), dict_values(['jg155', 1572, 'Justine Gill', 'jgill@yahoo.com']), dict_values(['jd328', 1911, 'Julee Doyle', 'jdoyle@gmail.com']), dict_values(['ld239', 65, 'Lisbeth Deliso', 'ldeliso@gmail.com']), dict_values(['cv918', 968, 'Carl Valdez', 'cvaldez@gmail.com']), dict_values(['kb145', 563, 'Kelyan Butler', 'kbutler@yahoo.com']), dict_values(['dw578', 65, 'Donat Weber', 'dweber@live.com']), dict_values(['ad511', 65, 'Alethia Delorme', 'adelorme@outlook.com']), dict_values(['db633', 65, 'Darrell Bernardi', 'dbernardi@yandex.com']), dict_values(['cr369', 65, 'Carina Reeves', 'creeves@gmail.com']), dict_values(['mr978', 65, 'Marvin Ruiz', 'mruiz@outlook.com']), dict_values(['md167', 1572, 'Mariabella Duerr', 'mduerr@live.com']), dict_values(['jr877', 1572, 'Jeni Ricco', 'jricco@live.com']), dict_values(['om753', 65, 'Otto Munoz', 'omunoz@yahoo.com']), dict_values(['ng231', 1114, 'Nesrine Gensch', 'ngensch@yandex.com']), dict_values(['tl316', 65, 'Tullio Lejeune', 'tlejeune@outlook.com']), dict_values(['dl139', 563, 'Dreama Lonardo', 'dlonardo@live.com']), dict_values(['mw253', 968, 'Maryrose West', 'mwest@live.com']), dict_values(['im424', 65, 'Irina Mays', 'imays@yandex.com']), dict_values(['mb131', 968, 'Marcelo Brose', 'mbrose@protonmail.com']), dict_values(['nc240', 1572, 'Nestor Coutant', 'ncoutant@gmail.com']), dict_values(['ab318', 1572, 'Aloysius Braun', 'abraun@live.com']), dict_values(['af301', 65, 'Amos Ferre', 'aferre@gmail.com']), dict_values(['bl736', 563, 'Brigitte Lynch', 'blynch@outlook.com']), dict_values(['ar957', 65, 'Alegra Ramsey', 'aramsey@yahoo.com']), dict_values(['cb474', 968, 'Conchita Beitel', 'cbeitel@gmail.com']), dict_values(['dv246', 1572, 'Donnie Vernet', 'dvernet@protonmail.com']), dict_values(['cj111', 563, 'Cyril Jones', 'cjones@protonmail.com']), dict_values(['lh765', 563, 'Lucinda Hays',  ...

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists. 
backer_info_df = pd.DataFrame(backer_values, columns=["backer_id", "cf_id", "name", "email"])
backer_info_df.head(10)
# Out:
#   backer_id  cf_id              name                  email
# 0     av166    968    Angelo Vincent      avincent@live.com
# 1     ha127    563     Hubert Arnold     harnold@yandex.com
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506    563        Lexie Hunt         lhunt@live.com
# 5     lh382    563     Lambert Huber        lhuber@live.com
# 6     em444    563        Emmy Morin        emorin@live.com
# 7     at582   1572     Armonda Trani        atrani@live.com
# 8     id772   1911        Ilana Duke      iduke@outlook.com
# 9     lw275     65     Leigha Wright       lwright@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_info_df.to_csv("backer_info_clean.csv", encoding='utf8', index=False)

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".

# %%
# Extract the name from the backer_info column and add it as a new column called "name".

# %%
# Extract the email from the backer_info column and add it as a new column called "email".

# %%
# Create a new DataFrame with the appropriate columns.

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backer_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Convert cf_id to an integer if necessary.

# %%
# Split the "name" column into "first_name" and "last_name" columns.
backer_info_df[["first_name", "last_name"]] = backer_info_df.name.str.split(expand=True)
backer_info_df.head(10)
# Out:
#   backer_id  cf_id              name                  email first_name  \
# 0     av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1     ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4     lh506    563        Lexie Hunt         lhunt@live.com      Lexie
# 5     lh382    563     Lambert Huber        lhuber@live.com    Lambert
# 6     em444    563        Emmy Morin        emorin@live.com       Emmy
# 7     at582   1572     Armonda Trani        atrani@live.com    Armonda
# 8     id772   1911        Ilana Duke      iduke@outlook.com      Ilana
# 9     lw275     65     Leigha Wright       lwright@live.com     Leigha
#
#   last_name
# 0   Vincent
# 1    Arnold
# 2    Goulet
# 3  Brunelli
# 4      Hunt
# 5     Huber
# 6     Morin
# 7     Trani
# 8      Duke
# 9    Wright

# %%
#  Drop the name column
backer_info_df = backer_info_df.drop("name", axis=1)
# Reorder the columns
backer_info_df = backer_info_df[["backer_id", "cf_id", "first_name", "last_name", "email"]]
backer_info_df.head(10)
# Out:
#   backer_id  cf_id first_name last_name                  email
# 0     av166    968     Angelo   Vincent      avincent@live.com
# 1     ha127    563     Hubert    Arnold     harnold@yandex.com
# 2     lg794     65      Loris    Goulet     lgoulet@yandex.com
# 3     tb566    563    Teodora  Brunelli  tbrunelli@outlook.com
# 4     lh506    563      Lexie      Hunt         lhunt@live.com
# 5     lh382    563    Lambert     Huber        lhuber@live.com
# 6     em444    563       Emmy     Morin        emorin@live.com
# 7     at582   1572    Armonda     Trani        atrani@live.com
# 8     id772   1911      Ilana      Duke      iduke@outlook.com
# 9     lw275     65     Leigha    Wright       lwright@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_info_df.to_csv("backer_info_clean.csv", encoding='utf8')
